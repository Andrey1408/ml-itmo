# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
import pandas as pd

# %%
train = pd.read_csv('persons_pics_train.csv')
x_train = train.drop('label', axis=1)
y_train = train['label']

x_test = pd.read_csv('persons_pics_reserved.csv')

tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4],
                     'C': [100], 'class_weight': [None, 'balanced'], 'random_state':[19]}]
cv = GridSearchCV(SVC(), tuned_parameters, refit=True, verbose=3)
cv.fit(x_train, y_train)
cv.best_params_
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END C=100, class_weight=None, gamma=0.001, kernel=rbf, random_state=19;, score=0.835 total time=   1.2s
# [CV 2/5] END C=100, class_weight=None, gamma=0.001, kernel=rbf, random_state=19;, score=0.838 total time=   1.1s
# [CV 3/5] END C=100, class_weight=None, gamma=0.001, kernel=rbf, random_state=19;, score=0.804 total time=   1.2s
# [CV 4/5] END C=100, class_weight=None, gamma=0.001, kernel=rbf, random_state=19;, score=0.819 total time=   1.3s
# [CV 5/5] END C=100, class_weight=None, gamma=0.001, kernel=rbf, random_state=19;, score=0.800 total time=   1.2s
# [CV 1/5] END C=100, class_weight=None, gamma=0.0001, kernel=rbf, random_state=19;, score=0.778 total time=   1.3s
# [CV 2/5] END C=100, class_weight=None, gamma=0.0001, kernel=rbf, random_state=19;, score=0.762 total time=   1.2s
# [CV 3/5] END C=100, class_weight=None, gamma=0.0001, kernel=rbf, random_state=19;, score=0.774 total time=   1.3s
# ...

# %%
print(list(cv.predict(x_test)))
# Out:
# ['George W Bush', 'Ariel Sharon', 'Tony Blair', 'Jacques Chirac', 'Tony Blair', 'Colin Powell', 'Donald Rumsfeld', 'Colin Powell', 'Tony Blair', 'Gerhard Schroeder', 'Donald Rumsfeld', 'Hugo Chavez', 'George W Bush', 'Hugo Chavez', 'Colin Powell', 'George W Bush', 'Ariel Sharon', 'Colin Powell', 'John Ashcroft', 'Gerhard Schroeder', 'Ariel Sharon', 'George W Bush', 'Ariel Sharon', 'George W Bush', 'George W Bush', 'Donald Rumsfeld', 'Donald Rumsfeld', 'Tony Blair', 'Serena Williams', 'Jean Chretien', 'George W Bush', 'George W Bush', 'George W Bush', 'George W Bush', 'George W Bush', 'Colin Powell', 'Donald Rumsfeld', 'Colin Powell', 'George W Bush', 'Gerhard Schroeder', 'Colin Powell', 'Donald Rumsfeld', 'Gerhard Schroeder', 'George W Bush', 'Tony Blair', 'George W Bush', 'George W Bush', 'Tony Blair', 'Colin Powell', 'Tony Blair', 'Serena Williams', 'Jean Chretien', 'Tony Blair', 'George W Bush', 'Colin Powell', 'George W Bush', 'George W Bush', 'George W Bush', 'George W Bush', 'G
# ...

# %%
C=1, class_weight=balanced, gamma=0.0001, kernel=poly, random_state=19;, score=0.083
C=100, class_weight=None, gamma=0.001, kernel=rbf, random_state=19;, score=0.838
# Out:
#   File "<ipython-input-17-1cd6ea8daf7d>", line 1
#     C=1, class_weight=balanced, gamma=0.0001, kernel=poly, random_state=19;, score=0.083
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?
